# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define the data
data = {
    'Model': ['IMCP', 'IMC', 'Weighted IMCP', 'IMCEP', '', 'Model 6'],
    'Train_Pearson': [0.978, 0.976, 0.978, 0.979, 0.979, 0.979],
    'Test_Pearson': [0.752, 0.742, 0.758, 0.757, 0.756, 0.758],
    'Train_RMSE': [0.49, 0.507, 0.497, 0.491, 0.497, 0.490],
    'Test_RMSE': [1.340, 1.360, 1.331, 1.334, 1.338, 1.333],
}

# Create DataFrame
df = pd.DataFrame(data).set_index('Model')

# Plot Pearson correlation
plt.figure(figsize=(14, 6))
df[['Train_Pearson', 'Test_Pearson']].plot(kind='bar')
plt.title('Train vs Test Pearson Correlation by Model')
plt.xlabel('Model')
plt.ylabel('Pearson Correlation (r)')
plt.legend(title='Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot RMSE
plt.figure(figsize=(14, 6))
df[['Train_RMSE', 'Test_RMSE']].plot(kind='bar')
plt.title('Train vs Test RMSE by Model')
plt.xlabel('Model')
plt.ylabel('Root Mean Square Error (RMSE)')
plt.legend(title='Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extracted RF and XGB2 train/test metrics for models 1-6
data = {
    'Model': ['IMCP', 'IMC', 'WIMCP', 'IMCEP', 'IMCPiEB', 'IMCEP2'],
    'RF_Train_Pearson': [0.978, 0.976, 0.978, 0.979, 0.979, 0.979],
    'RF_Test_Pearson': [0.752, 0.742, 0.758, 0.757, 0.756, 0.758],
    'XGB_Train_Pearson': [0.994, 0.981, 0.994, 0.996, 0.995, 0.996],
    'XGB_Test_Pearson': [0.745, 0.733, 0.741, 0.739, 0.751, 0.746],
    'RF_Train_RMSE': [0.495, 0.507, 0.497, 0.491, 0.497, 0.490],
    'RF_Test_RMSE': [1.340, 1.360, 1.331, 1.334, 1.338, 1.333],
    'XGB_Train_RMSE': [0.239, 0.422, 0.241, 0.190, 0.213, 0.193],
    'XGB_Test_RMSE': [1.348, 1.373, 1.357, 1.363, 1.336, 1.348],
}

df = pd.DataFrame(data).set_index('Model')

# Plot Pearson correlations for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_Pearson', 'RF_Test_Pearson', 'XGB_Train_Pearson', 'XGB_Test_Pearson']].plot(kind='bar')
plt.title('Train vs Test Pearson Correlation for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Pearson Correlation (r)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot RMSE for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_RMSE', 'RF_Test_RMSE', 'XGB_Train_RMSE', 'XGB_Test_RMSE']].plot(kind='bar')
plt.title('Train vs Test RMSE for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Root Mean Square Error (RMSE)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extracted RF and XGB2 train/test metrics for models 1-6
data = {
    'Model': ['IMCP', 'IMC', 'WIMCP', 'IMCEP', 'IMCPiEB', 'IMCEP2'],
    'RF_Train_Pearson': [0.978, 0.977, 0.978, 0.979, 0.980, 0.980],
    'RF_Test_Pearson': [0.753, 0.749, 0.753, 0.759, 0.765, 0.768],
    'XGB_Train_Pearson': [0.997, 0.991, 0.997, 0.999, 0.999, 0.999],
    'XGB_Test_Pearson': [0.752, 0.737, 0.751, 0.764, 0.752, 0.770],
    'RF_Train_RMSE': [0.496, 0.497, 0.494, 0.490, 0.498, 0.493],
    'RF_Test_RMSE': [1.343, 1.348, 1.342, 1.330, 1.326, 1.318],
    'XGB_Train_RMSE': [0.187, 0.295, 0.168, 0.120, 0.126, 0.110],
    'XGB_Test_RMSE': [1.334, 1.364, 1.334, 1.310, 1.332, 1.297],
}

df = pd.DataFrame(data).set_index('Model')

# Plot Pearson correlations for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_Pearson', 'RF_Test_Pearson', 'XGB_Train_Pearson', 'XGB_Test_Pearson']].plot(kind='bar')
plt.title('Train vs Test Pearson Correlation for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Pearson Correlation (r)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot RMSE for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_RMSE', 'RF_Test_RMSE', 'XGB_Train_RMSE', 'XGB_Test_RMSE']].plot(kind='bar')
plt.title('Train vs Test RMSE for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Root Mean Square Error (RMSE)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Extracted RF and XGB2 train/test metrics for models 1-6
data = {
    'Model': ['IMCP', 'IMC', 'WIMCP', 'IMCEP', 'IMCPiEB', 'IMCEP2'],
    'RF_Train_Pearson': [0.979, 0.978, 0.979, 0.979, 0.980, 0.980],
    'RF_Test_Pearson': [0.762, 0.760, 0.761, 0.759, 0.765, 0.768],
    'XGB_Train_Pearson': [0.996, 0.992, 0.998, 0.999, 0.999, 0.999],
    'XGB_Test_Pearson': [0.752, 0.747, 0.763, 0.764, 0.775, 0.770],
    'RF_Train_RMSE': [0.497, 0.493, 0.494, 0.490, 0.498, 0.493],
    'RF_Test_RMSE': [1.328, 1.348, 1.342, 1.330, 1.326, 1.318],
    'XGB_Train_RMSE': [0.193, 0.282, 0.153, 0.120, 0.126, 0.110],
    'XGB_Test_RMSE': [1.335, 1.343, 1.309, 1.310, 1.286, 1.297],
}

df = pd.DataFrame(data).set_index('Model')

# Plot Pearson correlations for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_Pearson', 'RF_Test_Pearson', 'XGB_Train_Pearson', 'XGB_Test_Pearson']].plot(kind='bar')
plt.title('Train vs Test Pearson Correlation for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Pearson Correlation (r)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot RMSE for RF and XGB2
plt.figure(figsize=(14, 6))
df[['RF_Train_RMSE', 'RF_Test_RMSE', 'XGB_Train_RMSE', 'XGB_Test_RMSE']].plot(kind='bar')
plt.title('Train vs Test RMSE for RF and XGB2 by Model')
plt.xlabel('Model Number')
plt.ylabel('Root Mean Square Error (RMSE)')
plt.legend(title='Algorithm & Dataset', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CV Pearson data with std dev for RF and XGB2 across models for 3 bins
data = {
    'Bin': np.repeat(['(0,12)','(0,6),(6,12)','(0,4),(4,8),(8,12)'], 6),
    'Model': ['IMCP', 'IMC', 'WIMCP', 'IMCEP', 'IMCPiEB', 'IMCEP2'] * 3,
    'RF_Pearson_Mean': [
        0.722, 0.706, 0.720, 0.728, 0.719, 0.729,
        0.722, 0.720, 0.723, 0.727, 0.719, 0.726,
        0.723, 0.725, 0.723, 0.728, 0.719, 0.726
    ],
    'RF_Pearson_STD': [
        0.024, 0.029, 0.025, 0.024, 0.024, 0.025,
        0.020, 0.024, 0.019, 0.019, 0.025, 0.024,
        0.021, 0.023, 0.021, 0.023, 0.025, 0.024
    ],
    'XGB2_Pearson_Mean': [
        0.716, 0.693, 0.712, 0.732, 0.711, 0.730,
        0.715, 0.713, 0.714, 0.723, 0.712, 0.719,
        0.716, 0.722, 0.715, 0.720, 0.712, 0.719
    ],
    'XGB2_Pearson_STD': [
        0.021, 0.032, 0.022, 0.023, 0.028, 0.019,
        0.021, 0.020, 0.018, 0.018, 0.025, 0.021,
        0.018, 0.019, 0.024, 0.022, 0.025, 0.021
    ]
}

df = pd.DataFrame(data)
bin_order = ['(0,12)', '(0,6),(6,12)', '(0,4),(4,8),(8,12)']
df['Bin'] = pd.Categorical(df['Bin'], categories=bin_order, ordered=True)
df = df.sort_values('Bin')  # Ensure correct order before pivot

# Now pivot
rf_pivot = df.pivot(index='Bin', columns='Model', values=['RF_Pearson_Mean', 'RF_Pearson_STD'])
xgb_pivot = df.pivot(index='Bin', columns='Model', values=['XGB2_Pearson_Mean', 'XGB2_Pearson_STD'])

# Common plotting parameters
bins = rf_pivot.index
models = rf_pivot['RF_Pearson_Mean'].columns.tolist()
x = np.arange(len(bins))
width = 0.8 / len(models)

# Plot for Random Forest
fig, ax = plt.subplots(figsize=(10,6))
for i, model in enumerate(models):
    means = rf_pivot['RF_Pearson_Mean'][model]
    stds = rf_pivot['RF_Pearson_STD'][model]
    ax.bar(x + i*width, means, width, yerr=stds, capsize=5, label=model)
ax.set_xticks(x + width*(len(models)-1)/2)
ax.set_xticklabels(bins)
ax.set_xlabel('Bin')
ax.set_ylabel('CV Pearson Correlation (r)')
ax.set_title('Random Forest CV Pearson by Bin and Model')
ax.legend(title='Model', bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot for XGB2
fig, ax = plt.subplots(figsize=(10,6))
for i, model in enumerate(models):
    means = xgb_pivot['XGB2_Pearson_Mean'][model]
    stds = xgb_pivot['XGB2_Pearson_STD'][model]
    ax.bar(x + i*width, means, width, yerr=stds, capsize=5, label=model)
ax.set_xticks(x + width*(len(models)-1)/2)
ax.set_xticklabels(bins)
ax.set_xlabel('Bin')
ax.set_ylabel('CV Pearson Correlation (r)')
ax.set_title('XGB CV Pearson by Bin and Model')
ax.legend(title='Model', bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CV Pearson data with std dev for RF and XGB2 across models for 3 bins
data = {
    'Bin': np.repeat(['(0,12)','(0,6),(6,12)','(0,4),(4,8),(8,12)'], 6),
    'Model': ['IMCP', 'IMC', 'WIMCP', 'IMCEP', 'IMCPiEB', 'IMCEP2'] * 3,
    'RF_RMSE_Mean': [
        1.350, 1.379, 1.353, 1.338, 1.358, 1.338,  # Bin1
        1.352, 1.428, 1.350, 1.343, 1.362, 1.345,  # Bin2
        1.351, 1.345, 1.352, 1.343, 1.361, 1.345   # Bin3
    ],
    'RF_RMSE_STD': [
        0.040, 0.042, 0.039, 0.039, 0.039, 0.039,
        0.040, 0.042, 0.039, 0.038, 0.030, 0.037,
        0.032, 0.039, 0.033, 0.034, 0.030, 0.031
    ],
    'XGB2_RMSE_Mean': [
        1.361, 1.405, 1.369, 1.326, 1.370, 1.331,
        1.364, 1.368, 1.366, 1.347, 1.363, 1.349,
        1.360, 1.349, 1.363, 1.352, 1.363, 1.355
    ],
    'XGB2_RMSE_STD': [
        0.035, 0.051, 0.036, 0.032, 0.048, 0.039,
        0.051, 0.042, 0.043, 0.040, 0.043, 0.038,
        0.043, 0.045, 0.039, 0.043, 0.031, 0.038
    ]
}

df = pd.DataFrame(data)
bin_order = ['(0,12)', '(0,6),(6,12)', '(0,4),(4,8),(8,12)']
df['Bin'] = pd.Categorical(df['Bin'], categories=bin_order, ordered=True)
df = df.sort_values('Bin')  # Ensure correct order before pivot

# Now pivot
rf_pivot = df.pivot(index='Bin', columns='Model', values=['RF_RMSE_Mean', 'RF_RMSE_STD'])
xgb_pivot = df.pivot(index='Bin', columns='Model', values=['XGB2_RMSE_Mean', 'XGB2_RMSE_STD'])

# Common plotting parameters
bins = rf_pivot.index
models = rf_pivot['RF_RMSE_Mean'].columns.tolist()
x = np.arange(len(bins))
width = 0.8 / len(models)

# Plot for Random Forest
fig, ax = plt.subplots(figsize=(10,6))
for i, model in enumerate(models):
    means = rf_pivot['RF_RMSE_Mean'][model]
    stds = rf_pivot['RF_RMSE_STD'][model]
    ax.bar(x + i*width, means, width, yerr=stds, capsize=5, label=model)
ax.set_xticks(x + width*(len(models)-1)/2)
ax.set_xticklabels(bins)
ax.set_xlabel('Bin')
ax.set_ylabel('CV RMSE Correlation (r)')
ax.set_title('Random Forest CV RMSE by Bin and Model')
ax.legend(title='Model', bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# Plot for XGB2
fig, ax = plt.subplots(figsize=(10,6))
for i, model in enumerate(models):
    means = xgb_pivot['XGB2_RMSE_Mean'][model]
    stds = xgb_pivot['XGB2_RMSE_STD'][model]
    ax.bar(x + i*width, means, width, yerr=stds, capsize=5, label=model)
ax.set_xticks(x + width*(len(models)-1)/2)
ax.set_xticklabels(bins)
ax.set_xlabel('Bin')
ax.set_ylabel('CV RMSE Correlation (r)')
ax.set_title('XGB CV RMSE by Bin and Model')
ax.legend(title='Model', bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define the data
data = {
    "Model": ["IMCP", "IMC", "WIMCP", "IMCEP", "IMCPiEB", "IMCEP2", "Pafnucy", "GraphDTA", "DataDTA"],
    "Test Pearson": [0.762, 0.760, 0.763, 0.767, 0.775, 0.770, 0.774, 0.660, 0.800],
    "Test RMSE": [1.328, 1.326, 1.309, 1.315, 1.286, 1.297, 1.129, 1.193, 1.012]
}

# Create DataFrame
df = pd.DataFrame(data)

# Set up plot style
sns.set(style="whitegrid")
x = range(len(df["Model"]))

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

width = 0.35

# Bars for Pearson
ax1.bar([i - width/2 for i in x], df["Test Pearson"], width=width, label='Test Pearson', color='skyblue')

# Bars for RMSE
ax2 = ax1.twinx()
ax2.bar([i + width/2 for i in x], df["Test RMSE"], width=width, label='Test RMSE', color='salmon')

# Formatting
ax1.set_xticks(x)
ax1.set_xticklabels(df["Model"], rotation=45, ha='right')
ax1.set_ylabel("Pearson")
ax2.set_ylabel("RMSE")
ax1.set_title("Comparison of Model Performance on Test Set")

# Combine legends
bars1 = ax1.patches
bars2 = ax2.patches
labels = ["Test Pearson", "Test RMSE"]
handles = [bars1[0], bars2[0]]
ax1.legend(handles, labels, loc="upper right")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Replace these with your full lists
pred  = np.array([
    6.657605, 5.5900135, 8.433532, 7.4532495, 5.686898, 6.544644, 6.9212837, 6.5775423, 6.6526814, 4.8168397,
    7.214667, 7.70285, 6.091928, 6.753866, 5.360069, 5.320822, 6.4141417, 6.459719, 9.683834, 4.570763,
    5.888649, 6.056466, 6.337389, 3.061983, 5.5244565, 5.0710683, 7.107313, 6.122708, 5.6926303, 6.647921,
    9.624955, 6.6184106, 6.828375, 5.7848287, 6.4619374, 4.978609, 7.181953, 5.898983, 6.963001, 7.7854342,
    5.722049, 6.699591, 7.6174755, 3.6161983, 7.284253, 4.2041993, 3.7356431, 5.857542, 6.9626365, 9.503951,
    5.845391, 4.3761406, 7.1928368, 6.770911, 8.342404, 5.8999133, 8.679124, 5.1762166, 7.1731167, 5.407839,
    5.292293, 5.549361, 5.3288584, 6.984454, 7.68593, 6.548954, 5.311528, 6.2905254, 5.651824, 5.597133,
    5.829518, 8.293107, 5.7542286, 5.880124, 4.5157967, 7.60053, 6.3644743, 8.202538, 5.2855816, 8.315603,
    8.328189, 8.391878, 7.7899885, 6.475334, 7.754009, 4.650187, 4.396434, 4.4812913, 4.1655316, 4.7341347,
    7.682417, 6.204638, 5.7088284, 10.93599, 5.3836293, 5.257026, 6.9020405, 5.708205, 8.366448, 8.642959,
    10.062144, 6.642573, 6.2307167, 5.124354, 5.36981, 5.905911, 5.9678035, 6.7475243, 7.3610544, 4.644005,
    3.0774763, 7.8380756, 8.274108, 5.318472, 8.730091, 5.676056, 8.155909, 4.9153266, 7.291156, 5.9050255,
    7.859641, 4.754277, 6.956501, 5.624734, 5.124632, 7.5203266, 9.128622, 7.337561, 6.286989, 7.352079,
    8.33508, 7.903096, 4.289004, 6.936205, 3.7229593, 6.41881, 6.488753, 7.594083, 4.722878, 5.823741,
    5.8485274, 7.529377, 7.3890486, 7.9336824, 4.035275, 7.984727, 6.209722, 5.5159593, 7.012715, 7.928529,
    5.8793654, 4.010411, 6.625389, 8.928661, 5.9800763, 5.924886, 7.6899443, 5.9483643, 8.784301, 4.25828,
    8.04244, 4.2452307, 6.0888314, 7.0933948, 4.686519, 9.980365, 7.5323286, 6.5079813, 6.2021837, 6.556406,
    6.117635, 4.295736, 5.5469303, 3.8683648, 4.2814183, 6.1605206, 5.7248983, 9.796596, 6.366776, 7.8095765,
    6.1258607, 6.2241755, 8.497673, 5.409611, 8.314037, 8.053912, 6.352747, 6.63006, 6.662564, 7.95505,
    4.22, 7.41, 4.26, 4.92, 8.54, 3.32, 5.3, 8.85, 6.37, 6.66, 3.17, 8.28,
    6.33, 10.59, 6.14, 3.88, 6.69, 3.3, 7.77, 4.59, 6.19, 7.89, 4.35, 3.98,
    9.22, 4.29, 4.5, 4.65, 5.85, 9.96, 9.29, 4.2, 5.89, 5.06, 8.66, 5.55,
    5.08, 8.38, 9.85, 4.49, 6.89, 8.17, 3.7, 4.96, 4.22, 2.7, 10.7, 10.57,
    9.85, 5.34, 7.15, 7.14, 5.66, 8.26, 4.62, 5.32, 7.05, 10.62, 4.85, 9.7,
    4.82, 7.22, 6.55, 7.96, 8.77, 6.6, 6.0, 8.44, 4.68, 5.51, 10.47, 7.43,
    6.95, 2.93, 4.3, 4.68, 3.84, 11.4, 6.66, 4.4, 9.22, 3.82, 6.7, 6.47,
    3.38, 6.49, 4.92, 10.37, 3.66, 4.6, 4.11, 5.7, 8.19, 7.48, 6.27, 6.43,
    6.77, 9.15, 5.86, 4.42, 5.84, 6.6, 6.12, 4.8, 6.23, 5.7, 4.8, 7.13,
    7.24, 4.03, 9.0, 5.15, 9.1, 3.92, 4.64, 5.74, 7.54, 2.0, 4.72, 5.97,
    9.0, 5.05, 7.46, 6.37, 5.17, 4.82, 6.1, 4.25, 6.02, 4.82, 5.7, 6.63,
    6.15, 7.96, 7.07, 9.52, 4.15, 5.66, 7.09, 6.66, 7.74, 8.26, 2.0, 7.74,
    6.43, 6.05, 7.85, 8.22, 4.03, 7.12, 8.55, 5.1, 4.66, 5.25, 6.67, 10.82,
    7.8, 7.1, 3.47, 5.82, 8.72, 7.71, 8.87, 7.64, 6.1, 7.49, 3.72, 3.9,
    7.85, 4.8, 7.95, 10.19, 5.04, 5.44, 7.7, 9.2, 9.64, 8.3, 3.3, 4.79,
    6.7, 5.15, 4.92, 6.68, 4.89, 4.14, 5.24, 7.13, 6.06, 3.62, 4.11, 7.64,
    3.47, 2.21, 8.0, 8.05, 7.8, 3.13, 3.46, 6.89, 7.51, 8.03, 6.11, 5.8,
    6.05, 7.62, 4.61, 6.68, 7.19, 3.7, 8.69, 5.78, 7.19, 5.7, 5.79, 3.4,
    5.77, 9.57, 5.33, 9.05, 6.54, 8.89, 5.92, 4.65, 9.03, 4.1, 3.46, 8.74,
    8.55, 7.85, 4.4, 5.05, 5.2, 8.0, 5.7, 6.0, 3.47, 7.14, 8.43, 5.77,
    4.35, 5.8, 3.37, 2.64, 5.75, 7.19, 4.03, 7.15, 2.3, 4.31, 6.17, 8.22,
    5.68, 2.17, 4.43, 5.96, 6.52, 6.92, 6.97, 5.11, 7.92, 6.27, 2.19, 4.41,
    7.0, 6.48, 6.62, 7.84, 3.9, 8.34, 6.44, 8.4, 8.0, 9.1, 3.28, 6.8,
    8.11, 5.28, 2.44, 6.55, 4.71, 6.0, 5.47, 4.34, 4.41, 7.38, 8.74, 3.34,
    8.85, 8.6, 3.26, 7.6, 4.7
])


# Create the plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.hist(pred - test, bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Pred − Test')
plt.ylabel('Frequency')
plt.title('Histogram of Differences')
plt.grid(True)
plt.tight_layout()
plt.show()
